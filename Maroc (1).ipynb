# %%
import pandas as pd

# %%
df1 = pd.read_csv('emplois_IT_maroc.csv')

# %%
df1.head()
# Out:
#                                                Titre  \
# 0  Ingénieur Commercial en IT ou Télécom - Marrakech
# 1                      DataOps Engineer - Casablanca
# 2                              Technicien IT - Rabat
# 3                Stagiaire Technicien IT - Marrakech
# 4                         Technicien IT  - Bouskoura
#
#                    Entreprise        Date  \
# 0                 JOB CONNECT  13.06.2025
# 1  VISION BUSINESS CONSULTING  13.06.2025
# 2      TECTRA RABAT - KENITRA  04.06.2025
# 3                   BEINTERIM  14.05.2025
# 4                   SEPALUMIC  13.05.2025
#
#                                          Description  \
# 0  Nous recrutons pour le compte de notre client ...
# 1  Nous recherchons un(e)  DataOps Engineer  expé...
# 2  Nous sommes à la recherche d'un  Technicien IT...
# 3  Nous sommes a la recherche pour l'un de nos cl...
# 4  Nous sommes à la recherche d'un  Technicien IT...
#
#                        Niveau d'études  \
# 0                        Bac+5 et plus
# 1                        Bac+5 et plus
# 2  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 3  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 4         Bac+3, Bac+4 & Bac+5 et plus
#
#                                           Expérience    Contrat  \
# 0  Expérience entre 5 ans et 10 ans & Expérience ...        CDI
# 1  Expérience entre 5 ans et 10 ans & Expérience ...  Freelance
# 2                           Débutant < 2 ans et plus    Intérim
# 3                            Etudiant, jeune diplômé      Stage
# 4            Expérience entre 2 ans et 5 ans et plus        CDI
#
#                   Région                                     Compétences  \
# 0         Marrakech-Safi                                             NaN
# 1  Casablanca-Mohammedia      APACHE - DOCKER - GITLAB - JENKINS - SPARK
# 2     Rabat-Salé-Kénitra                                             NaN
# 3         Marrakech-Safi                                             NaN
# 4  Casablanca-Mohammedia  FORTINET - MICROSOFT - TCP IP - VEEAM - VMWARE
#
#                                                 Lien
# 0  https://www.emploi.ma/offre-emploi-maroc/ingen...
# 1  https://www.emploi.ma/offre-emploi-maroc/datao...
# 2  https://www.emploi.ma/offre-emploi-maroc/techn...
# 3  https://www.emploi.ma/offre-emploi-maroc/stagi...
# 4  https://www.emploi.ma/offre-emploi-maroc/techn...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Titre            86 non-null     object
#  1   Entreprise       86 non-null     object
#  2   Date             86 non-null     object
#  3   Description      86 non-null     object
#  4   Niveau d'études  86 non-null     object
#  5   Expérience       86 non-null     object
#  6   Contrat          86 non-null     object
#  7   Région           86 non-null     object
#  8   Compétences      77 non-null     object
#  9   Lien             86 non-null     object
# dtypes: object(10)
# memory usage: 6.8+ KB

# %%
df2 = df1[['Titre','Entreprise','Date',"Niveau d'études" ,'Expérience' ,'Contrat'	,'Compétences']]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Titre            86 non-null     object
#  1   Entreprise       86 non-null     object
#  2   Date             86 non-null     object
#  3   Niveau d'études  86 non-null     object
#  4   Expérience       86 non-null     object
#  5   Contrat          86 non-null     object
#  6   Compétences      77 non-null     object
# dtypes: object(7)
# memory usage: 4.8+ KB

# %%
df2
# Out:
#                                                 Titre  \
# 0   Ingénieur Commercial en IT ou Télécom - Marrakech
# 1                       DataOps Engineer - Casablanca
# 2                               Technicien IT - Rabat
# 3                 Stagiaire Technicien IT - Marrakech
# 4                          Technicien IT  - Bouskoura
# ..                                                ...
# 81                    Technicien Support - Casablanca
# 82  Professeurs Permanents en Design Graphique - C...
# 83  Professeur Permanent en Informatique  - Casabl...
# 84           Développeur Profil DevOps (H/F)  - Rabat
# 85             Responsable Applicatif IT - Casablanca
#
#                          Entreprise        Date  \
# 0                       JOB CONNECT  13.06.2025
# 1        VISION BUSINESS CONSULTING  13.06.2025
# 2            TECTRA RABAT - KENITRA  04.06.2025
# 3                         BEINTERIM  14.05.2025
# 4                         SEPALUMIC  13.05.2025
# ..                              ...         ...
# 81                      LACAISSE.MA  30.04.2025
# 82  EDVANTIS HIGHER EDUCATION GROUP  25.04.2025
# 83  EDVANTIS HIGHER EDUCATION GROUP  25.04.2025
# 84                    YCN DEV MAROC  24.04.2025
# 85       VISION BUSINESS CONSULTING  23.04.2025
#
#                         Niveau d'études  \
# 0                         Bac+5 et plus
# 1                         Bac+5 et plus
# 2   Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 3   Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 4          Bac+3, Bac+4 & Bac+5 et plus
# ..                                  ...
# 81  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 82                        Bac+5 et plus
# 83                        Bac+5 et plus
# 84  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 85                        Bac+5 et plus
#
#                                            Expérience           Contrat  \
# 0   Expérience entre 5 ans et 10 ans & Expérience ...               CDI
# 1   Expérience entre 5 ans et 10 ans & Expérience ...         Freelance
# 2                            Débutant < 2 ans et plus           Intérim
# 3                             Etudiant, jeune diplômé             Stage
# 4             Expérience entre 2 ans et 5 ans et plus               CDI
# ..                                                ...               ...
# 81                           Débutant < 2 ans et plus  CDI, CDD & Stage
# 82            Expérience entre 2 ans et 5 ans et plus               CDI
# 83            Expérience entre 2 ans et 5 ans et plus               CDI
# 84                    Etudiant, jeune diplômé et plus         CDI & CDD
# 85            Expérience entre 2 ans et 5 ans et plus         Freelance
#
#                                           Compétences
# 0                                                 NaN
# 1          APACHE - DOCKER - GITLAB - JENKINS - SPARK
# 2                                                 NaN
# 3                                                 NaN
# 4      FORTINET - MICROSOFT - TCP IP - VEEAM - VMWARE
# ..                                                ...
# 81                                                NaN
# 82                                             Design
# 83                                       Enseignement
# 84  APACHE - Assurance - BASH - CLUSTER - Comptabi...
# 85  CICS - COBOL - DB2 - JCL - LINUX - ORACLE - SQ...
#
# [86 rows x 7 columns]

# %%
# l' ajoute du colonne Localisation

df2[['Titre', 'Localisation']] = df2['Titre'].str.split(' - ',  n = 1, expand=True)
# Out:
# C:\Users\Administrateur\AppData\Local\Temp\ipykernel_3052\336126782.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['Titre', 'Localisation']] = df2['Titre'].str.split(' - ',  n = 1, expand=True)
# C:\Users\Administrateur\AppData\Local\Temp\ipykernel_3052\336126782.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['Titre', 'Localisation']] = df2['Titre'].str.split(' - ',  n = 1, expand=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Titre            86 non-null     object
#  1   Entreprise       86 non-null     object
#  2   Date             86 non-null     object
#  3   Niveau d'études  86 non-null     object
#  4   Expérience       86 non-null     object
#  5   Contrat          86 non-null     object
#  6   Compétences      77 non-null     object
#  7   Localisation     40 non-null     object
# dtypes: object(8)
# memory usage: 5.5+ KB

# %%
df2.head()
# Out:
#                                    Titre                  Entreprise  \
# 0  Ingénieur Commercial en IT ou Télécom                 JOB CONNECT
# 1                       DataOps Engineer  VISION BUSINESS CONSULTING
# 2                          Technicien IT      TECTRA RABAT - KENITRA
# 3                Stagiaire Technicien IT                   BEINTERIM
# 4                         Technicien IT                    SEPALUMIC
#
#          Date                      Niveau d'études  \
# 0  13.06.2025                        Bac+5 et plus
# 1  13.06.2025                        Bac+5 et plus
# 2  04.06.2025  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 3  14.05.2025  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 4  13.05.2025         Bac+3, Bac+4 & Bac+5 et plus
#
#                                           Expérience    Contrat  \
# 0  Expérience entre 5 ans et 10 ans & Expérience ...        CDI
# 1  Expérience entre 5 ans et 10 ans & Expérience ...  Freelance
# 2                           Débutant < 2 ans et plus    Intérim
# 3                            Etudiant, jeune diplômé      Stage
# 4            Expérience entre 2 ans et 5 ans et plus        CDI
#
#                                       Compétences Localisation
# 0                                             NaN    Marrakech
# 1      APACHE - DOCKER - GITLAB - JENKINS - SPARK   Casablanca
# 2                                             NaN        Rabat
# 3                                             NaN    Marrakech
# 4  FORTINET - MICROSOFT - TCP IP - VEEAM - VMWARE    Bouskoura

# %%
df2.isnull().sum()
# Out:
# Titre               0
# Entreprise          0
# Date                0
# Niveau d'études     0
# Expérience          0
# Contrat             0
# Compétences         9
# Localisation       46
# dtype: int64

# %%
df2.describe()
# Out:
#                 Titre   Entreprise        Date Niveau d'études  \
# count              86           86          86              86
# unique             67           23          24              10
# top     Technicien IT  AFRICASHORE  04.06.2025           Bac+3
# freq                4           44          48              44
#
#                               Expérience               Contrat Compétences  \
# count                                 86                    86          77
# unique                                11                     8          58
# top     Expérience entre 5 ans et 10 ans  CDI, CDD - Freelance         SAP
# freq                                  38                    37           3
#
#        Localisation
# count            40
# unique           11
# top      Casablanca
# freq             20

# %%
df2
# Out:
#                                          Titre  \
# 0        Ingénieur Commercial en IT ou Télécom
# 1                             DataOps Engineer
# 2                                Technicien IT
# 3                      Stagiaire Technicien IT
# 4                               Technicien IT
# ..                                         ...
# 81                          Technicien Support
# 82  Professeurs Permanents en Design Graphique
# 83       Professeur Permanent en Informatique
# 84            Développeur Profil DevOps (H/F)
# 85                   Responsable Applicatif IT
#
#                          Entreprise        Date  \
# 0                       JOB CONNECT  13.06.2025
# 1        VISION BUSINESS CONSULTING  13.06.2025
# 2            TECTRA RABAT - KENITRA  04.06.2025
# 3                         BEINTERIM  14.05.2025
# 4                         SEPALUMIC  13.05.2025
# ..                              ...         ...
# 81                      LACAISSE.MA  30.04.2025
# 82  EDVANTIS HIGHER EDUCATION GROUP  25.04.2025
# 83  EDVANTIS HIGHER EDUCATION GROUP  25.04.2025
# 84                    YCN DEV MAROC  24.04.2025
# 85       VISION BUSINESS CONSULTING  23.04.2025
#
#                         Niveau d'études  \
# 0                         Bac+5 et plus
# 1                         Bac+5 et plus
# 2   Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 3   Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 4          Bac+3, Bac+4 & Bac+5 et plus
# ..                                  ...
# 81  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 82                        Bac+5 et plus
# 83                        Bac+5 et plus
# 84  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 85                        Bac+5 et plus
#
#                                            Expérience           Contrat  \
# 0   Expérience entre 5 ans et 10 ans & Expérience ...               CDI
# 1   Expérience entre 5 ans et 10 ans & Expérience ...         Freelance
# 2                            Débutant < 2 ans et plus           Intérim
# 3                             Etudiant, jeune diplômé             Stage
# 4             Expérience entre 2 ans et 5 ans et plus               CDI
# ..                                                ...               ...
# 81                           Débutant < 2 ans et plus  CDI, CDD & Stage
# 82            Expérience entre 2 ans et 5 ans et plus               CDI
# 83            Expérience entre 2 ans et 5 ans et plus               CDI
# 84                    Etudiant, jeune diplômé et plus         CDI & CDD
# 85            Expérience entre 2 ans et 5 ans et plus         Freelance
#
#                                           Compétences Localisation
# 0                                                 NaN    Marrakech
# 1          APACHE - DOCKER - GITLAB - JENKINS - SPARK   Casablanca
# 2                                                 NaN        Rabat
# 3                                                 NaN    Marrakech
# 4      FORTINET - MICROSOFT - TCP IP - VEEAM - VMWARE    Bouskoura
# ..                                                ...          ...
# 81                                                NaN   Casablanca
# 82                                             Design   Casablanca
# 83                                       Enseignement   Casablanca
# 84  APACHE - Assurance - BASH - CLUSTER - Comptabi...        Rabat
# 85  CICS - COBOL - DB2 - JCL - LINUX - ORACLE - SQ...   Casablanca
#
# [86 rows x 8 columns]

# %%
# !pip install missingno
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: missingno in c:\users\administrateur\appdata\roaming\python\python312\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\administrateur\appdata\roaming\python\python312\site-packages (from missingno) (1.26.4)
# Requirement already satisfied: matplotlib in c:\anaconda3\lib\site-packages (from missingno) (3.9.2)
# Requirement already satisfied: scipy in c:\anaconda3\lib\site-packages (from missingno) (1.13.1)
# Requirement already satisfied: seaborn in c:\anaconda3\lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\anaconda3\lib\site-packages (from matplotlib->missingno) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda3\lib\site-packages (from matplotlib->missingno) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda3\lib\site-packages (from matplotlib->missingno) (24.1)
# Requirement already satisfied: pillow>=8 in c:\anaconda3\lib\site-packages (from matplotlib->missingno) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\anaconda3\lib\site-packages (from matplotlib->missingno) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anaconda3\lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\anaconda3\lib\site-packages (from seaborn->missingno) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
import missingno as msno
msno.bar(df2)
# Out:
# <Axes: >

# %%
msno.matrix(df2)
# Out:
# <Axes: >

# %%
df2.isnull().sum()
# Out:
# Titre               0
# Entreprise          0
# Date                0
# Niveau d'études     0
# Expérience          0
# Contrat             0
# Compétences         9
# Localisation       46
# dtype: int64

# %%
df2[['jour','mois','année']] = df2['Date'].str.split('.' ,expand = True )
# Out:
# C:\Users\Administrateur\AppData\Local\Temp\ipykernel_3052\2575249004.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['jour','mois','année']] = df2['Date'].str.split('.' ,expand = True )

# %%
df2
# Out:
#                                          Titre  \
# 0        Ingénieur Commercial en IT ou Télécom
# 1                             DataOps Engineer
# 2                                Technicien IT
# 3                      Stagiaire Technicien IT
# 4                               Technicien IT
# ..                                         ...
# 81                          Technicien Support
# 82  Professeurs Permanents en Design Graphique
# 83       Professeur Permanent en Informatique
# 84            Développeur Profil DevOps (H/F)
# 85                   Responsable Applicatif IT
#
#                          Entreprise        Date  \
# 0                       JOB CONNECT  13.06.2025
# 1        VISION BUSINESS CONSULTING  13.06.2025
# 2            TECTRA RABAT - KENITRA  04.06.2025
# 3                         BEINTERIM  14.05.2025
# 4                         SEPALUMIC  13.05.2025
# ..                              ...         ...
# 81                      LACAISSE.MA  30.04.2025
# 82  EDVANTIS HIGHER EDUCATION GROUP  25.04.2025
# 83  EDVANTIS HIGHER EDUCATION GROUP  25.04.2025
# 84                    YCN DEV MAROC  24.04.2025
# 85       VISION BUSINESS CONSULTING  23.04.2025
#
#                         Niveau d'études  \
# 0                         Bac+5 et plus
# 1                         Bac+5 et plus
# 2   Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 3   Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 4          Bac+3, Bac+4 & Bac+5 et plus
# ..                                  ...
# 81  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 82                        Bac+5 et plus
# 83                        Bac+5 et plus
# 84  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 85                        Bac+5 et plus
#
#                                            Expérience           Contrat  \
# 0   Expérience entre 5 ans et 10 ans & Expérience ...               CDI
# 1   Expérience entre 5 ans et 10 ans & Expérience ...         Freelance
# 2                            Débutant < 2 ans et plus           Intérim
# 3                             Etudiant, jeune diplômé             Stage
# 4             Expérience entre 2 ans et 5 ans et plus               CDI
# ..                                                ...               ...
# 81                           Débutant < 2 ans et plus  CDI, CDD & Stage
# 82            Expérience entre 2 ans et 5 ans et plus               CDI
# 83            Expérience entre 2 ans et 5 ans et plus               CDI
# 84                    Etudiant, jeune diplômé et plus         CDI & CDD
# 85            Expérience entre 2 ans et 5 ans et plus         Freelance
#
#                                           Compétences Localisation jour mois  \
# 0                                                 NaN    Marrakech   13   06
# 1          APACHE - DOCKER - GITLAB - JENKINS - SPARK   Casablanca   13   06
# 2                                                 NaN        Rabat   04   06
# 3                                                 NaN    Marrakech   14   05
# 4      FORTINET - MICROSOFT - TCP IP - VEEAM - VMWARE    Bouskoura   13   05
# ..                                                ...          ...  ...  ...
# 81                                                NaN   Casablanca   30   04
# 82                                             Design   Casablanca   25   04
# 83                                       Enseignement   Casablanca   25   04
# 84  APACHE - Assurance - BASH - CLUSTER - Comptabi...        Rabat   24   04
# 85  CICS - COBOL - DB2 - JCL - LINUX - ORACLE - SQ...   Casablanca   23   04
#
#    année
# 0   2025
# 1   2025
# 2   2025
# 3   2025
# 4   2025
# ..   ...
# 81  2025
# 82  2025
# 83  2025
# 84  2025
# 85  2025
#
# [86 rows x 11 columns]

# %%
def detect_domaine(Titre):
    poste = str(Titre).lower()
    
    if any(word in poste for word in ['data analyst', 'business analyst', 'data scientist', 'analyst', 'business intelligence analyst', 
                                      'data visualization analyst', 'quantitative analyst', 'operations research analyst','dataeps engineer',
                                      'intelligence artificielle', 'machine learning','dataops engineer','test validation engineer',
                                      'test automation engineer','cloud computing and vitulisation enginner']):
        return 'Data Science'
        
    # Développement
    elif any(word in poste for word in ['développeur', 'developpeur', 'dev', 'développement logiciel', 'fullstack', 
                                        'backend', 'frontend', 'vhdl', 'c++', 'java', 'python', 'embarqué', 'logiciel', 'interconnect', 
                                        'software engineer','ingénieur commercial en it ou Télécom	']):
        return 'Développement'
        
    # Cybersécurité
    elif any(word in poste for word in ['cyber', 'cybersécurité', 'sécurité', 'conformité', 'gouvernance', 'isp',
                                        'integration of security in projects']):
        return 'Cybersécurité'
        
    # Infrastructure
    
    elif any(word in poste for word in ['réseau', 'système', 'infra', 'administrateur', 'windows server', 'serveur'
                                        , 'cloud', 'architecte technique', 'architecte système', 'hpc', 'exploit', 'exploitant', 'ldap',
                                        'sso', 'responsable informatique', 'it sme', 'transition manager']):
        return 'Infrastructure'
        
    # Gestion de projet
    elif any(word in poste for word in ['chef de projet', 'project manager', 'scrum', 'agile', 'product owner', 'moa', 'projets',
                                        'pmo', 'pilotage', 'coordonnateur', 'programme', 'run manager', 'proxy po', 'appui pilotage',
                                        'chargé de projet']):
        return 'Gestion de projet'
        
    # Tests / Validation
    elif any(word in poste for word in ['testeur', 'test', 'qa', 'validation', 'recette']):
        return 'Tests / Validation'
        
    # Support technique
    elif any(word in poste for word in ['technicien', 'support', 'maintenance', 'helpdesk', 'parc informatique', 'opérateur pc',
                                        'correspondant informatique', 'suivi technique']):
        return 'Support technique'
        
    # SIG / Cartographie
    elif any(word in poste for word in ['cartographe', 'sig', 'géomatique']):
        return 'SIG / Cartographie'
        
    # Conseil / ERP / AMOA
    elif any(word in poste for word in ['consultant', 'amoa', 'fonctionnel', 'avant-vente', 'sap', 'oracle', 'ebs', 'sirh']):
        return 'Conseil / ERP / AMOA'
        
    # Systèmes métiers
    elif any(word in poste for word in ['crm', 'référentiels', 'assistant recette']):
        return 'Systèmes métiers'
        
    # Formation / Alternance
    elif any(word in poste for word in ['apprenti', 'alternant', 'bachelor', 'formation']):
        return 'Formation / Alternance'

    
    # Architecture SI
    elif any(word in poste for word in ['architecte d\'entreprise', 'architecte applicatif', 'responsable domaine it',
                                        'responsable applicatif it', 'architecte']):
        return 'Architecture SI'
    else:
        return 'Autre'

# %%
df2['domaine_IT'] = df2['Titre'].apply(detect_domaine)

# %%
df2
# Out:
#                                          Titre  \
# 0        Ingénieur Commercial en IT ou Télécom
# 1                             DataOps Engineer
# 2                                Technicien IT
# 3                      Stagiaire Technicien IT
# 4                               Technicien IT
# ..                                         ...
# 81                          Technicien Support
# 82  Professeurs Permanents en Design Graphique
# 83       Professeur Permanent en Informatique
# 84            Développeur Profil DevOps (H/F)
# 85                   Responsable Applicatif IT
#
#                          Entreprise        Date  \
# 0                       JOB CONNECT  13.06.2025
# 1        VISION BUSINESS CONSULTING  13.06.2025
# 2            TECTRA RABAT - KENITRA  04.06.2025
# 3                         BEINTERIM  14.05.2025
# 4                         SEPALUMIC  13.05.2025
# ..                              ...         ...
# 81                      LACAISSE.MA  30.04.2025
# 82  EDVANTIS HIGHER EDUCATION GROUP  25.04.2025
# 83  EDVANTIS HIGHER EDUCATION GROUP  25.04.2025
# 84                    YCN DEV MAROC  24.04.2025
# 85       VISION BUSINESS CONSULTING  23.04.2025
#
#                         Niveau d'études  \
# 0                         Bac+5 et plus
# 1                         Bac+5 et plus
# 2   Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 3   Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 4          Bac+3, Bac+4 & Bac+5 et plus
# ..                                  ...
# 81  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 82                        Bac+5 et plus
# 83                        Bac+5 et plus
# 84  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 85                        Bac+5 et plus
#
#                                            Expérience           Contrat  \
# 0   Expérience entre 5 ans et 10 ans & Expérience ...               CDI
# 1   Expérience entre 5 ans et 10 ans & Expérience ...         Freelance
# 2                            Débutant < 2 ans et plus           Intérim
# 3                             Etudiant, jeune diplômé             Stage
# 4             Expérience entre 2 ans et 5 ans et plus               CDI
# ..                                                ...               ...
# 81                           Débutant < 2 ans et plus  CDI, CDD & Stage
# 82            Expérience entre 2 ans et 5 ans et plus               CDI
# 83            Expérience entre 2 ans et 5 ans et plus               CDI
# 84                    Etudiant, jeune diplômé et plus         CDI & CDD
# 85            Expérience entre 2 ans et 5 ans et plus         Freelance
#
#                                           Compétences Localisation jour mois  \
# 0                                                 NaN    Marrakech   13   06
# 1          APACHE - DOCKER - GITLAB - JENKINS - SPARK   Casablanca   13   06
# 2                                                 NaN        Rabat   04   06
# 3                                                 NaN    Marrakech   14   05
# 4      FORTINET - MICROSOFT - TCP IP - VEEAM - VMWARE    Bouskoura   13   05
# ..                                                ...          ...  ...  ...
# 81                                                NaN   Casablanca   30   04
# 82                                             Design   Casablanca   25   04
# 83                                       Enseignement   Casablanca   25   04
# 84  APACHE - Assurance - BASH - CLUSTER - Comptabi...        Rabat   24   04
# 85  CICS - COBOL - DB2 - JCL - LINUX - ORACLE - SQ...   Casablanca   23   04
#
#    année          domaine_IT
# 0   2025               Autre
# 1   2025        Data Science
# 2   2025   Support technique
# 3   2025   Support technique
# 4   2025   Support technique
# ..   ...                 ...
# 81  2025   Support technique
# 82  2025  SIG / Cartographie
# 83  2025               Autre
# 84  2025       Développement
# 85  2025     Architecture SI
#
# [86 rows x 12 columns]

# %%
df2.isnull().sum()
# Out:
# Titre               0
# Entreprise          0
# Date                0
# Niveau d'études     0
# Expérience          0
# Contrat             0
# Compétences         9
# Localisation       46
# jour                0
# mois                0
# année               0
# domaine_IT          0
# dtype: int64

# %%
df2['Type contrat'] = df2['Contrat'].str.extract(r'^(CDI|CDD|Stage|Freelance)', expand=False)

# %%
df2
# Out:
#                                          Titre  \
# 0        Ingénieur Commercial en IT ou Télécom
# 1                             DataOps Engineer
# 2                                Technicien IT
# 3                      Stagiaire Technicien IT
# 4                               Technicien IT
# ..                                         ...
# 81                          Technicien Support
# 82  Professeurs Permanents en Design Graphique
# 83       Professeur Permanent en Informatique
# 84            Développeur Profil DevOps (H/F)
# 85                   Responsable Applicatif IT
#
#                          Entreprise        Date  \
# 0                       JOB CONNECT  13.06.2025
# 1        VISION BUSINESS CONSULTING  13.06.2025
# 2            TECTRA RABAT - KENITRA  04.06.2025
# 3                         BEINTERIM  14.05.2025
# 4                         SEPALUMIC  13.05.2025
# ..                              ...         ...
# 81                      LACAISSE.MA  30.04.2025
# 82  EDVANTIS HIGHER EDUCATION GROUP  25.04.2025
# 83  EDVANTIS HIGHER EDUCATION GROUP  25.04.2025
# 84                    YCN DEV MAROC  24.04.2025
# 85       VISION BUSINESS CONSULTING  23.04.2025
#
#                         Niveau d'études  \
# 0                         Bac+5 et plus
# 1                         Bac+5 et plus
# 2   Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 3   Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 4          Bac+3, Bac+4 & Bac+5 et plus
# ..                                  ...
# 81  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 82                        Bac+5 et plus
# 83                        Bac+5 et plus
# 84  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 85                        Bac+5 et plus
#
#                                            Expérience           Contrat  \
# 0   Expérience entre 5 ans et 10 ans & Expérience ...               CDI
# 1   Expérience entre 5 ans et 10 ans & Expérience ...         Freelance
# 2                            Débutant < 2 ans et plus           Intérim
# 3                             Etudiant, jeune diplômé             Stage
# 4             Expérience entre 2 ans et 5 ans et plus               CDI
# ..                                                ...               ...
# 81                           Débutant < 2 ans et plus  CDI, CDD & Stage
# 82            Expérience entre 2 ans et 5 ans et plus               CDI
# 83            Expérience entre 2 ans et 5 ans et plus               CDI
# 84                    Etudiant, jeune diplômé et plus         CDI & CDD
# 85            Expérience entre 2 ans et 5 ans et plus         Freelance
#
#                                           Compétences Localisation jour mois  \
# 0                                                 NaN    Marrakech   13   06
# 1          APACHE - DOCKER - GITLAB - JENKINS - SPARK   Casablanca   13   06
# 2                                                 NaN        Rabat   04   06
# 3                                                 NaN    Marrakech   14   05
# 4      FORTINET - MICROSOFT - TCP IP - VEEAM - VMWARE    Bouskoura   13   05
# ..                                                ...          ...  ...  ...
# 81                                                NaN   Casablanca   30   04
# 82                                             Design   Casablanca   25   04
# 83                                       Enseignement   Casablanca   25   04
# 84  APACHE - Assurance - BASH - CLUSTER - Comptabi...        Rabat   24   04
# 85  CICS - COBOL - DB2 - JCL - LINUX - ORACLE - SQ...   Casablanca   23   04
#
#    année          domaine_IT Type contrat
# 0   2025               Autre          CDI
# 1   2025        Data Science    Freelance
# 2   2025   Support technique          NaN
# 3   2025   Support technique        Stage
# 4   2025   Support technique          CDI
# ..   ...                 ...          ...
# 81  2025   Support technique          CDI
# 82  2025  SIG / Cartographie          CDI
# 83  2025               Autre          CDI
# 84  2025       Développement          CDI
# 85  2025     Architecture SI    Freelance
#
# [86 rows x 13 columns]

# %%
df2.isnull().sum()
# Out:
# Titre               0
# Entreprise          0
# Date                0
# Niveau d'études     0
# Expérience          0
# Contrat             0
# Compétences         9
# Localisation       46
# jour                0
# mois                0
# année               0
# domaine_IT          0
# Type contrat        5
# dtype: int64

# %%
 import numpy as np
df2['domaine_IT'] = df2['domaine_IT'].replace('Autre',np.nan)

# %%
df2
# Out:
#                                          Titre  \
# 0        Ingénieur Commercial en IT ou Télécom
# 1                             DataOps Engineer
# 2                                Technicien IT
# 3                      Stagiaire Technicien IT
# 4                               Technicien IT
# ..                                         ...
# 81                          Technicien Support
# 82  Professeurs Permanents en Design Graphique
# 83       Professeur Permanent en Informatique
# 84            Développeur Profil DevOps (H/F)
# 85                   Responsable Applicatif IT
#
#                          Entreprise        Date  \
# 0                       JOB CONNECT  13.06.2025
# 1        VISION BUSINESS CONSULTING  13.06.2025
# 2            TECTRA RABAT - KENITRA  04.06.2025
# 3                         BEINTERIM  14.05.2025
# 4                         SEPALUMIC  13.05.2025
# ..                              ...         ...
# 81                      LACAISSE.MA  30.04.2025
# 82  EDVANTIS HIGHER EDUCATION GROUP  25.04.2025
# 83  EDVANTIS HIGHER EDUCATION GROUP  25.04.2025
# 84                    YCN DEV MAROC  24.04.2025
# 85       VISION BUSINESS CONSULTING  23.04.2025
#
#                         Niveau d'études  \
# 0                         Bac+5 et plus
# 1                         Bac+5 et plus
# 2   Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 3   Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 4          Bac+3, Bac+4 & Bac+5 et plus
# ..                                  ...
# 81  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 82                        Bac+5 et plus
# 83                        Bac+5 et plus
# 84  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 85                        Bac+5 et plus
#
#                                            Expérience           Contrat  \
# 0   Expérience entre 5 ans et 10 ans & Expérience ...               CDI
# 1   Expérience entre 5 ans et 10 ans & Expérience ...         Freelance
# 2                            Débutant < 2 ans et plus           Intérim
# 3                             Etudiant, jeune diplômé             Stage
# 4             Expérience entre 2 ans et 5 ans et plus               CDI
# ..                                                ...               ...
# 81                           Débutant < 2 ans et plus  CDI, CDD & Stage
# 82            Expérience entre 2 ans et 5 ans et plus               CDI
# 83            Expérience entre 2 ans et 5 ans et plus               CDI
# 84                    Etudiant, jeune diplômé et plus         CDI & CDD
# 85            Expérience entre 2 ans et 5 ans et plus         Freelance
#
#                                           Compétences Localisation jour mois  \
# 0                                                 NaN    Marrakech   13   06
# 1          APACHE - DOCKER - GITLAB - JENKINS - SPARK   Casablanca   13   06
# 2                                                 NaN        Rabat   04   06
# 3                                                 NaN    Marrakech   14   05
# 4      FORTINET - MICROSOFT - TCP IP - VEEAM - VMWARE    Bouskoura   13   05
# ..                                                ...          ...  ...  ...
# 81                                                NaN   Casablanca   30   04
# 82                                             Design   Casablanca   25   04
# 83                                       Enseignement   Casablanca   25   04
# 84  APACHE - Assurance - BASH - CLUSTER - Comptabi...        Rabat   24   04
# 85  CICS - COBOL - DB2 - JCL - LINUX - ORACLE - SQ...   Casablanca   23   04
#
#    année          domaine_IT Type contrat
# 0   2025                 NaN          CDI
# 1   2025        Data Science    Freelance
# 2   2025   Support technique          NaN
# 3   2025   Support technique        Stage
# 4   2025   Support technique          CDI
# ..   ...                 ...          ...
# 81  2025   Support technique          CDI
# 82  2025  SIG / Cartographie          CDI
# 83  2025                 NaN          CDI
# 84  2025       Développement          CDI
# 85  2025     Architecture SI    Freelance
#
# [86 rows x 13 columns]

# %%
df2.isnull().sum()
# Out:
# Titre               0
# Entreprise          0
# Date                0
# Niveau d'études     0
# Expérience          0
# Contrat             0
# Compétences         9
# Localisation       46
# jour                0
# mois                0
# année               0
# domaine_IT         19
# Type contrat        5
# dtype: int64

# %%
#remplacer les valeur manquante par la mode

for col in df2.columns:
    mode_col = df2[col].mode().values[0]
    df2[col] = df2[col].fillna(mode_col)

# %%
df2
# Out:
#                                          Titre  \
# 0        Ingénieur Commercial en IT ou Télécom
# 1                             DataOps Engineer
# 2                                Technicien IT
# 3                      Stagiaire Technicien IT
# 4                               Technicien IT
# ..                                         ...
# 81                          Technicien Support
# 82  Professeurs Permanents en Design Graphique
# 83       Professeur Permanent en Informatique
# 84            Développeur Profil DevOps (H/F)
# 85                   Responsable Applicatif IT
#
#                          Entreprise        Date  \
# 0                       JOB CONNECT  13.06.2025
# 1        VISION BUSINESS CONSULTING  13.06.2025
# 2            TECTRA RABAT - KENITRA  04.06.2025
# 3                         BEINTERIM  14.05.2025
# 4                         SEPALUMIC  13.05.2025
# ..                              ...         ...
# 81                      LACAISSE.MA  30.04.2025
# 82  EDVANTIS HIGHER EDUCATION GROUP  25.04.2025
# 83  EDVANTIS HIGHER EDUCATION GROUP  25.04.2025
# 84                    YCN DEV MAROC  24.04.2025
# 85       VISION BUSINESS CONSULTING  23.04.2025
#
#                         Niveau d'études  \
# 0                         Bac+5 et plus
# 1                         Bac+5 et plus
# 2   Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 3   Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 4          Bac+3, Bac+4 & Bac+5 et plus
# ..                                  ...
# 81  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 82                        Bac+5 et plus
# 83                        Bac+5 et plus
# 84  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 85                        Bac+5 et plus
#
#                                            Expérience           Contrat  \
# 0   Expérience entre 5 ans et 10 ans & Expérience ...               CDI
# 1   Expérience entre 5 ans et 10 ans & Expérience ...         Freelance
# 2                            Débutant < 2 ans et plus           Intérim
# 3                             Etudiant, jeune diplômé             Stage
# 4             Expérience entre 2 ans et 5 ans et plus               CDI
# ..                                                ...               ...
# 81                           Débutant < 2 ans et plus  CDI, CDD & Stage
# 82            Expérience entre 2 ans et 5 ans et plus               CDI
# 83            Expérience entre 2 ans et 5 ans et plus               CDI
# 84                    Etudiant, jeune diplômé et plus         CDI & CDD
# 85            Expérience entre 2 ans et 5 ans et plus         Freelance
#
#                                           Compétences Localisation jour mois  \
# 0                                                 SAP    Marrakech   13   06
# 1          APACHE - DOCKER - GITLAB - JENKINS - SPARK   Casablanca   13   06
# 2                                                 SAP        Rabat   04   06
# 3                                                 SAP    Marrakech   14   05
# 4      FORTINET - MICROSOFT - TCP IP - VEEAM - VMWARE    Bouskoura   13   05
# ..                                                ...          ...  ...  ...
# 81                                                SAP   Casablanca   30   04
# 82                                             Design   Casablanca   25   04
# 83                                       Enseignement   Casablanca   25   04
# 84  APACHE - Assurance - BASH - CLUSTER - Comptabi...        Rabat   24   04
# 85  CICS - COBOL - DB2 - JCL - LINUX - ORACLE - SQ...   Casablanca   23   04
#
#    année          domaine_IT Type contrat
# 0   2025       Développement          CDI
# 1   2025        Data Science    Freelance
# 2   2025   Support technique          CDI
# 3   2025   Support technique        Stage
# 4   2025   Support technique          CDI
# ..   ...                 ...          ...
# 81  2025   Support technique          CDI
# 82  2025  SIG / Cartographie          CDI
# 83  2025       Développement          CDI
# 84  2025       Développement          CDI
# 85  2025     Architecture SI    Freelance
#
# [86 rows x 13 columns]

# %%
df2.isnull().sum()
# Out:
# Titre              0
# Entreprise         0
# Date               0
# Niveau d'études    0
# Expérience         0
# Contrat            0
# Compétences        0
# Localisation       0
# jour               0
# mois               0
# année              0
# domaine_IT         0
# Type contrat       0
# dtype: int64

# %%
df2.to_csv("Dataset_Maroc_final.csv")

# %%
df2
# Out:
#                                          Titre  \
# 0        Ingénieur Commercial en IT ou Télécom
# 1                             DataOps Engineer
# 2                                Technicien IT
# 3                      Stagiaire Technicien IT
# 4                               Technicien IT
# ..                                         ...
# 81                          Technicien Support
# 82  Professeurs Permanents en Design Graphique
# 83       Professeur Permanent en Informatique
# 84            Développeur Profil DevOps (H/F)
# 85                   Responsable Applicatif IT
#
#                          Entreprise        Date  \
# 0                       JOB CONNECT  13.06.2025
# 1        VISION BUSINESS CONSULTING  13.06.2025
# 2            TECTRA RABAT - KENITRA  04.06.2025
# 3                         BEINTERIM  14.05.2025
# 4                         SEPALUMIC  13.05.2025
# ..                              ...         ...
# 81                      LACAISSE.MA  30.04.2025
# 82  EDVANTIS HIGHER EDUCATION GROUP  25.04.2025
# 83  EDVANTIS HIGHER EDUCATION GROUP  25.04.2025
# 84                    YCN DEV MAROC  24.04.2025
# 85       VISION BUSINESS CONSULTING  23.04.2025
#
#                         Niveau d'études  \
# 0                         Bac+5 et plus
# 1                         Bac+5 et plus
# 2   Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 3   Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 4          Bac+3, Bac+4 & Bac+5 et plus
# ..                                  ...
# 81  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 82                        Bac+5 et plus
# 83                        Bac+5 et plus
# 84  Bac+2, Bac+3, Bac+4 & Bac+5 et plus
# 85                        Bac+5 et plus
#
#                                            Expérience           Contrat  \
# 0   Expérience entre 5 ans et 10 ans & Expérience ...               CDI
# 1   Expérience entre 5 ans et 10 ans & Expérience ...         Freelance
# 2                            Débutant < 2 ans et plus           Intérim
# 3                             Etudiant, jeune diplômé             Stage
# 4             Expérience entre 2 ans et 5 ans et plus               CDI
# ..                                                ...               ...
# 81                           Débutant < 2 ans et plus  CDI, CDD & Stage
# 82            Expérience entre 2 ans et 5 ans et plus               CDI
# 83            Expérience entre 2 ans et 5 ans et plus               CDI
# 84                    Etudiant, jeune diplômé et plus         CDI & CDD
# 85            Expérience entre 2 ans et 5 ans et plus         Freelance
#
#                                           Compétences Localisation jour mois  \
# 0                                                 SAP    Marrakech   13   06
# 1          APACHE - DOCKER - GITLAB - JENKINS - SPARK   Casablanca   13   06
# 2                                                 SAP        Rabat   04   06
# 3                                                 SAP    Marrakech   14   05
# 4      FORTINET - MICROSOFT - TCP IP - VEEAM - VMWARE    Bouskoura   13   05
# ..                                                ...          ...  ...  ...
# 81                                                SAP   Casablanca   30   04
# 82                                             Design   Casablanca   25   04
# 83                                       Enseignement   Casablanca   25   04
# 84  APACHE - Assurance - BASH - CLUSTER - Comptabi...        Rabat   24   04
# 85  CICS - COBOL - DB2 - JCL - LINUX - ORACLE - SQ...   Casablanca   23   04
#
#    année          domaine_IT Type contrat
# 0   2025       Développement          CDI
# 1   2025        Data Science    Freelance
# 2   2025   Support technique          CDI
# 3   2025   Support technique        Stage
# 4   2025   Support technique          CDI
# ..   ...                 ...          ...
# 81  2025   Support technique          CDI
# 82  2025  SIG / Cartographie          CDI
# 83  2025       Développement          CDI
# 84  2025       Développement          CDI
# 85  2025     Architecture SI    Freelance
#
# [86 rows x 13 columns]

# %%
msno.matrix(df2)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

df2['domaine_IT'].value_counts().plot.bar(figsize=(12,6))
plt.title("Répartiton des offres par doamaine IT") 
plt.ylabel('Nombres des offres')
# Out:
# Text(0, 0.5, 'Nombres des offres')

# %%
df_it_mois_annee = df2.groupby(['année', 'mois']).size().reset_index(name='count')

# Créer un graphique à aire
for annee in df_it_mois_annee['année'].unique():
    df_it_mois_annee_annee = df_it_mois_annee[df_it_mois_annee['année'] == annee]
    plt.fill_between(df_it_mois_annee_annee['mois'], df_it_mois_annee_annee['count'], label=annee, alpha=0.5)

plt.xlabel('Mois')
plt.ylabel('Nombre de demandes')
plt.title('Évolution des demandes IT pour 2025')
plt.legend()
plt.show()

# %%
# Grouper les données par domaine et compétence
df_grouped = df2.groupby(['domaine_IT', 'Compétences']).size().reset_index(name='count')

# Trier les données par domaine et nombre de compétences
df_grouped = df_grouped.sort_values(['domaine_IT', 'count'], ascending=[True, False])

# Afficher les compétences les plus fréquentes pour chaque domaine
for domaine in df_grouped['domaine_IT'].unique():
    df_domaine = df_grouped[df_grouped['domaine_IT'] == domaine]
    print(f"Domaine : {domaine}")
    print(df_domaine.head(5))  # Afficher les 5 compétences les plus fréquentes
    print()
# Out:
# Domaine : Architecture SI
#         domaine_IT                                        Compétences  count
# 1  Architecture SI  CICS - COBOL - DB2 - JCL - LINUX - ORACLE - SQ...      2
# 0  Architecture SI                                    ATLAS - MONGODB      1
#
# Domaine : Conseil / ERP / AMOA
#              domaine_IT                                        Compétences  \
# 2  Conseil / ERP / AMOA                                         ABAP - SAP
# 5  Conseil / ERP / AMOA                                        REACH - SAP
# 6  Conseil / ERP / AMOA                                                SAP
# 3  Conseil / ERP / AMOA  API - LINUX - POSTGRESQL - PYTHON - REST - UBU...
# 4  Conseil / ERP / AMOA  Formation - Gestion - Management - Processus M...
#
#    count
# 2      2
# 5      2
# 6      2
# 3      1
# 4      1
#
# Domaine : Cybersécurité
#       domaine_IT                                        Compétences  count
# 7  Cybersécurité  CVS - ENDPOINT - IDEAL - JAVASCRIPT - PYTHON - VM      2
#
# Domaine : Data Science
#      domaine_IT                                        Compétences  count
# 8  Data Science         APACHE - DOCKER - GITLAB - JENKINS - SPARK      1
# 9  Data Science  API - CVS - GIT - GITLAB - JAVASCRIPT - JENKIN...      1
#
# Domaine : Développement
#        domaine_IT                                        Compétences  count
# 10  Développement  ACCESS - AGILE - ARM - AZURE - COSMOS - CVS - ...      2
# 14  Développement  AGILE - CVS - GIT - MERCURIAL - REST - SCRUM -...      2
# 31  Développement  BGP - CISCO - CVS - DHCP - DNS - ETHERNET - JU...      2
# 32  Développement  BOOTSTRAP - CSS - CVS - GIT - JAVA - JAVASCRIP...      2
# 40  Développement                                               SAGE      2
#
# Domaine : Gestion de projet
#            domaine_IT                                        Compétences  \
# 42  Gestion de projet   AGILE - API - POSTGRESQL - PYTHON - REST - SCRUM
# 43  Gestion de projet  AGILE - AZURE - Gestion - JIRA - Leadership - ...
#
#     count
# 42      1
# 43      1
#
# Domaine : Infrastructure
#         domaine_IT                                        Compétences  count
# 45  Infrastructure  AGILE - ALM - BASH - CVS - DNS - DOCKER - HTTP...      2
# 46  Infrastructure  AGILE - API - ARM - AZURE - C# - COSMOS - CVS ...      2
# 47  Infrastructure                                        AGILE - CVS      2
# 48  Infrastructure  API - ARM - BGP - CVS - IAM - PUPPET - PYTHON ...      2
# 50  Infrastructure  AZURE - CENTOS - CVS - DOCKER - LINUX - PERL -...      2
#
# Domaine : SIG / Cartographie
#             domaine_IT                                        Compétences  \
# 54  SIG / Cartographie  AJAX - BOOTSTRAP - CSS - CVS - GIT - HTML - IL...
# 55  SIG / Cartographie                                             Design
#
#     count
# 54      1
# 55      1
#
# Domaine : Support technique
#            domaine_IT                                        Compétences  \
# 58  Support technique                                                SAP
# 57  Support technique     FORTINET - MICROSOFT - TCP IP - VEEAM - VMWARE
# 56  Support technique  CAO - Conception Assistée par Ordinateur - Men...
#
#     count
# 58      9
# 57      2
# 56      1
#
# Domaine : Tests / Validation
#             domaine_IT                                        Compétences  \
# 59  Tests / Validation  AGILE - API - APP - CVS - JAVA - MAVEN - MYSQL...
# 60  Tests / Validation                                  CVS - RHEL - SUSE
#
#     count
# 59      2
# 60      1

# %%
for domaine in df_grouped['domaine_IT'].unique():
    df_domaine = df_grouped[df_grouped['domaine_IT'] == domaine].head(5)
    plt.figure(figsize=(10, 6))
    plt.bar(df_domaine['Compétences'], df_domaine['count'])
    plt.title(f"Compétences les plus fréquentes dans le domaine {domaine}")
    plt.xlabel('Compétence')
    plt.ylabel('Fréquence')
    plt.show()

# %%
# Grouper les données par domaine et titre
df_grouped = df2.groupby(['domaine_IT', 'Titre']).size().reset_index(name='count')

# Trier les données par domaine et nombre de  titre
df_grouped = df_grouped.sort_values(['domaine_IT', 'count'], ascending=[True, False])

# Afficher les titre les plus fréquentes pour chaque domaine
for domaine in df_grouped['domaine_IT'].unique():
    df_domaine = df_grouped[df_grouped['domaine_IT'] == domaine]
    print(f"Domaine : {domaine}")
    print(df_domaine.head(5))  # Afficher les 5 compétences les plus fréquentes
    print()
# Out:
# Domaine : Architecture SI
#         domaine_IT                                             Titre  count
# 1  Architecture SI                         Responsable Applicatif IT      2
# 0  Architecture SI  Lead Data Engineer / Architecte Data (Freelance)      1
#
# Domaine : Conseil / ERP / AMOA
#              domaine_IT                                     Titre  count
# 4  Conseil / ERP / AMOA                  Consultant SAP EHS (H/F)      2
# 2  Conseil / ERP / AMOA              Consultant Fonctionnel Odoo       1
# 3  Conseil / ERP / AMOA                 Consultant SAP ABAP (H/F)      1
# 5  Conseil / ERP / AMOA             Consultant SAP FI-CO/PS (H/F)      1
# 6  Conseil / ERP / AMOA  Consultant SAP MM/SD/EWM/PP/QM/CAR (H/F)      1
#
# Domaine : Cybersécurité
#       domaine_IT                          Titre  count
# 9  Cybersécurité  Cyber Security Engineer (M/F)      2
#
# Domaine : Data Science
#       domaine_IT                           Titre  count
# 10  Data Science                DataOps Engineer      1
# 11  Data Science  Test Automation Engineer (M/F)      1
#
# Domaine : Développement
#        domaine_IT                            Titre  count
# 13  Développement  AZURE Solutions Architect (M/F)      2
# 33  Développement          Network Architect (M/F)      2
# 38  Développement            REACT Developer (M/F)      2
# 40  Développement                  Responsable SI       2
# 41  Développement            SWIFT Developer (M/F)      2
#
# Domaine : Gestion de projet
#            domaine_IT                                              Titre  \
# 44  Gestion de projet                          Chef de Projet Odoo & CRM
# 45  Gestion de projet  Product Owner Senior – Secteur Recrutement (Pr...
#
#     count
# 44      1
# 45      1
#
# Domaine : Infrastructure
#         domaine_IT                             Titre  count
# 46  Infrastructure         AWS Cloud Architect (M/F)      2
# 48  Infrastructure             Cloud Architect (M/F)      2
# 50  Infrastructure              Cloud Engineer (M/F)      2
# 52  Infrastructure  Cloud System Administrator (M/F)      2
# 53  Infrastructure     Cloud System Integrator (M/F)      2
#
# Domaine : SIG / Cartographie
#             domaine_IT                                       Titre  count
# 56  SIG / Cartographie  Professeurs Permanents en Design Graphique      1
# 57  SIG / Cartographie                      UX / UI Designer (M/F)      1
#
# Domaine : Support technique
#            domaine_IT                    Titre  count
# 60  Support technique            Technicien IT      4
# 58  Support technique  Stagiaire Technicien IT      2
# 61  Support technique           Technicien IT       2
# 59  Support technique    Technicien Help Desk       1
# 62  Support technique            Technicien SI      1
#
# Domaine : Tests / Validation
#             domaine_IT                               Titre  count
# 65  Tests / Validation                     QA Tester (M/F)      2
# 66  Tests / Validation  Test and Validation Engineer (M/F)      1

# %%
for domaine in df_grouped['domaine_IT'].unique() :
    df_domaine = df_grouped[df_grouped['domaine_IT'] == domaine].head(5) # Afficher les 5  domiane  les plus fréquentes
    plt.figure(figsize = (18 , 6))
    plt.bar(df_domaine['Titre'] , df_domaine['count'])
    plt.xticks(rotation=90) # Faire pivoter les étiquettes de l'axe x
    plt.title(domaine) # Ajouter un titre pour chaque graphique
    plt.tight_layout() # Ajuster la mise en page pour éviter les coupures
    plt.show()
